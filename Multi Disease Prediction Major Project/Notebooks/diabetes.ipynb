# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\multiple-disease-prediction-final\multiple-disease-prediction-final\Dataset\diabetes.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23840\1792816266.py in <module>
# ----> 1 data = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\multiple-disease-prediction-final\multiple-disease-prediction-final\Notebooks\diabetes.csv")
#       2 data.head()
#
# c:\Users\hp\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\Users\hp\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\Users\hp\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\Users\hp\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# c:\Users\hp\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:\\Users\\hp\\OneDrive\\Desktop\\multiple-disease-prediction-final\\multiple-disease-prediction-final\\Notebooks\\diabetes.csv' does not exist: b'C:\\Users\\hp\\OneDrive\\Desktop\\multiple-disease-prediction-final\\multiple-disease-prediction-final\\Notebooks\\diabetes.csv'

# %%
data.shape
# Out:
# (2000, 9)

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10164\4134831140.py in <module>
# ----> 1 data.isnull().sum()
#
# NameError: name 'data' is not defined

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.120405       0.149672      -0.063375
# Glucose                      0.120405  1.000000       0.138044       0.062368
# BloodPressure                0.149672  0.138044       1.000000       0.198800
# SkinThickness               -0.063375  0.062368       0.198800       1.000000
# Insulin                     -0.076600  0.320371       0.087384       0.448859
# BMI                          0.019475  0.226864       0.281545       0.393760
# DiabetesPedigreeFunction    -0.025453  0.123243       0.051331       0.178299
# Age                          0.539457  0.254496       0.238375      -0.111034
# Outcome                      0.224437  0.458421       0.075958       0.076040
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.076600  0.019475                 -0.025453
# Glucose                   0.320371  0.226864                  0.123243
# BloodPressure             0.087384  0.281545                  0.051331
# SkinThickness             0.448859  0.393760                  0.178299
# Insulin                   1.000000  0.223012                  0.192719
# BMI                       0.223012  1.000000                  0.125719
# DiabetesPedigreeFunction  0.192719  0.125719                  1.000000
# Age                      -0.085879  0.038987                  0.026569
# Outcome                   0.120924  0.276726                  0.155459
#
#                                Age   Outcome
# Pregnancies               0.539457  0.224437
# Glucose                   0.254496  0.458421
# BloodPressure             0.238375  0.075958
# SkinThickness            -0.111034  0.076040
# Insulin                  -0.085879  0.120924
# BMI                       0.038987  0.276726
# DiabetesPedigreeFunction  0.026569  0.155459
# Age                       1.000000  0.236509
# Outcome                   0.236509  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %%
X = data.iloc[:,:-1]
y = data['Outcome']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10164\658459149.py in <module>
# ----> 1 X = data.iloc[:,:-1]
#       2 y = data['Outcome']
#
# NameError: name 'data' is not defined

# %%
X.shape
# Out:
# (2000, 8)

# %%
y.shape
# Out:
# (2000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
print("Train Set: ", X_train.shape, y_train.shape)
print("Test Set: ", X_test.shape, y_test.shape)
# Out:
# Train Set:  (1600, 8) (1600,)
# Test Set:  (400, 8) (400,)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=20)
model.fit(X_train, y_train)
#97



# from sklearn.svm import SVC
# model = SVC()
# model.fit(X_train,y_train)
#80

# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression(solver = 'liblinear',multi_class='ovr')
# model.fit(X_train,y_train)
#80

# from sklearn.neighbors import KNeighborsClassifier
# model = KNeighborsClassifier()
# model.fit(X_train, y_train)
#79.77

# from sklearn.naive_bayes import GaussianNB
# model = GaussianNB()
# model.fit(X_train, y_train)
#71.428

# from sklearn.tree import DecisionTreeClassifier
# model = DecisionTreeClassifier()
# model.fit(X_train,y_train)
# #96.25
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, model.predict(X_test))*100)
# Out:
# 98.25

# %%
import pickle

# %%
pickle.dump(model, open("diabetes.pkl",'wb'))
